# %% [markdown]
# <a href="https://colab.research.google.com/github/venkidev21/23it060-AIML-Assignment-/blob/main/AIML(ASS-2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data (1) - insurance_data (1).csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='x',color='red')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 8    62
# 25   54
# 13   29
# 6    55
# 21   26
# 15   55

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
X_test
y_predicted = model.predict(X_test)

# %%
model.score(X_test,y_test)
y_predicted
X_test
model.coef_
model.intercept_
# Out:
# array([-5.64063543])

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -1.53
    y = sigmoid(z)
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.4850044983805899

# %%
age = 43
prediction_function(age)
# Out:
# 0.568565299077705
